# %%
import os
import pandas as pd
import uuid
from datetime import datetime

# %%
def check_labels_file(folder):
    subfolders = os.listdir(folder)
    dfs = []
    for i, sf in enumerate(subfolders):
        user_folder = os.path.join(folder,sf)
        labels_file = os.path.join(user_folder, 'labels.txt')
        if os.path.exists(labels_file):
            print('Reading user %s ---------------------------' % (sf))
check_labels_file('single_sample')
# Out:
# Reading user 010 ---------------------------

# %%
''' 
Ao ler os usuários, verificar a existência do arquivo labels.txt
'''
def create_base_dataframes(folder):
    subfolders = os.listdir(folder)
    dfs = []
    
    # df com cada linha sendo uma trajetória classificada
    transport_df = pd.DataFrame(columns=['Start Time','End Time','Transportation Mode'])
    
    # df com cada linha sendo um registro de gps com o identificador da trajetória
    gps_points_df = pd.DataFrame(columns=['Identifier', 'Timestamp', 'Latitude', 'Longitude', 'Altitude', 'Label'])
    
    for i, sf in enumerate(subfolders):
        user_folder = os.path.join(folder,sf)
        labels_file = os.path.join(user_folder, 'labels.txt')
        
        print('Reading user %s ---------------------------' % (sf))
        
        # cria uma tabela do usuário em que cada linha é uma trajetória
        u_transport_df = pd.read_csv(labels_file, sep="\t")
        u_transport_df['Identifier'] = 0
        
        transport_df = pd.concat((transport_df,u_transport_df),axis=0)
        # cria uma tabela do usuário que contém todos os seus registros de gps
#             u_gps_points_df = pd.DataFrame(columns=['Identifier', 'Timestamp', 'Latitude', 'Longitude', 'Altitude', 'Label'])
            
        plt_files = os.path.join(user_folder, 'Trajectory')
        
        for filename in os.listdir(plt_files): 
            u_gps_points_df = pd.read_csv(os.path.join(plt_files, filename), skiprows=6, header=None,
                                  parse_dates=[[5, 6]], infer_datetime_format=True)
            u_gps_points_df.rename(inplace=True, columns={'5_6': 'Timestamp', 0: 'Latitude', 
                                                  1: 'Longitude', 3: 'Altitude'})
            u_gps_points_df.drop(inplace=True, columns=[2, 4])
        
            gps_points_df = pd.concat((gps_points_df,u_gps_points_df),axis=0)
    
    return transport_df,gps_points_df

def label_trajectories(transport_df,gps_points_df):
    count = 1
    total = transport_df.shape[0]
    for index_transport,row_transport in transport_df.iterrows():
        print('Processing trajectory (%s/%s)' % (count,total))
        
        identifier = uuid.uuid1() # identifiers are repeating in trajectories. How to create unique ones?
        
        transport_df.loc[index_transport, 'Identifier'] = identifier
        
        start = datetime.strptime(row_transport['Start Time'],'%Y/%m/%d %H:%M:%S')
        end = datetime.strptime(row_transport['End Time'],'%Y/%m/%d %H:%M:%S')
        label = row_transport['Transportation Mode']
        
        for index_gps,row_gps in gps_points_df.iterrows():
            if start <= row_gps['Timestamp'] <= end:
                gps_points_df.loc[index_gps,'Identifier'] = identifier
                gps_points_df.loc[index_gps,'Label'] = label
                
        count += 1
        
    return transport_df,gps_points_df

# %%
trajectories,gps_points_df = create_base_dataframes('single_sample')
trajectories,gps_points_df = label_trajectories(trajectories,gps_points_df)
# Out:
# Reading user 010 ---------------------------
# Processing trajectory (1/434)
# Processing trajectory (2/434)
# Processing trajectory (3/434)
# Processing trajectory (4/434)
# Processing trajectory (5/434)
# Processing trajectory (6/434)
# Processing trajectory (7/434)
# Processing trajectory (8/434)
# Processing trajectory (9/434)
# Processing trajectory (10/434)
# Processing trajectory (11/434)
# Processing trajectory (12/434)
# Processing trajectory (13/434)
# Processing trajectory (14/434)
# Processing trajectory (15/434)
# Processing trajectory (16/434)
# Processing trajectory (17/434)
# Processing trajectory (18/434)
# Processing trajectory (19/434)
# Processing trajectory (20/434)
# Processing trajectory (21/434)
# Processing trajectory (22/434)
# Processing trajectory (23/434)
# Processing trajectory (24/434)
# Processing trajectory (25/434)
# Processing trajectory (26/434)
# Processing trajectory (27/434)
# Processing trajectory (28/434)
# Processing trajectory (29/434)
# Processing trajectory (30/434)
# Processing trajectory (31/434)
# Processing trajectory (32/434)
# Processing trajectory (33/434)
# Processing trajectory (34/434)
# Processing trajectory (35/434)
# Processing trajectory (36/434)
# Processing trajectory (37/434)
# Processing trajectory (38/434)
# Processing trajectory (39/434)
# Processing trajectory (40/434)
# Processing trajectory (41/434)
# Processing trajectory (42/434)
# Processing trajectory (43/434)
# Processing trajectory (44/434)
# Processing trajectory (45/434)
# Processing trajectory (46/434)
# Processing trajectory (47/434)
# Processing trajectory (48/434)
# Processing trajectory (49/434)
# Processing trajectory (50/434)
# Processing trajectory (51/434)
# Processing trajectory (52/434)
# Processing trajectory (53/434)
# Processing trajectory (54/434)
# Processing trajectory (55/434)
# Processing trajectory (56/434)
# Processing trajectory (57/434)
# Processing trajectory (58/434)
# Processing trajectory (59/434)
# Processing trajectory (60/434)
# Processing trajectory (61/434)
# Processing trajectory (62/434)
# Processing trajectory (63/434)
# Processing trajectory (64/434)
# Processing trajectory (65/434)
# Processing trajectory (66/434)
# Processing trajectory (67/434)
# Processing trajectory (68/434)
# Processing trajectory (69/434)
# Processing trajectory (70/434)
# Processing trajectory (71/434)
# Processing trajectory (72/434)
# Processing trajectory (73/434)
# Processing trajectory (74/434)
# Processing trajectory (75/434)
# Processing trajectory (76/434)
# Processing trajectory (77/434)
# Processing trajectory (78/434)
# Processing trajectory (79/434)
# Processing trajectory (80/434)
# Processing trajectory (81/434)
# Processing trajectory (82/434)
# Processing trajectory (83/434)
# Processing trajectory (84/434)
# Processing trajectory (85/434)
# Processing trajectory (86/434)
# Processing trajectory (87/434)
# Processing trajectory (88/434)
# Processing trajectory (89/434)
# Processing trajectory (90/434)
# Processing trajectory (91/434)
# Processing trajectory (92/434)
# Processing trajectory (93/434)
# Processing trajectory (94/434)
# Processing trajectory (95/434)
# Processing trajectory (96/434)
# Processing trajectory (97/434)
# Processing trajectory (98/434)
# Processing trajectory (99/434)
# Processing trajectory (100/434)
# Processing trajectory (101/434)
# Processing trajectory (102/434)
# Processing trajectory (103/434)
# Processing trajectory (104/434)
# Processing trajectory (105/434)
# Processing trajectory (106/434)
# Processing trajectory (107/434)
# Processing trajectory (108/434)
# Processing trajectory (109/434)
# Processing trajectory (110/434)
# Processing trajectory (111/434)
# Processing trajectory (112/434)
# Processing trajectory (113/434)
# Processing trajectory (114/434)
# Processing trajectory (115/434)
# Processing trajectory (116/434)
# Processing trajectory (117/434)
# Processing trajectory (118/434)
# Processing trajectory (119/434)
# Processing trajectory (120/434)
# Processing trajectory (121/434)
# Processing trajectory (122/434)
# Processing trajectory (123/434)
# Processing trajectory (124/434)
# Processing trajectory (125/434)
# Processing trajectory (126/434)
# Processing trajectory (127/434)
# Processing trajectory (128/434)
# Processing trajectory (129/434)
# Processing trajectory (130/434)
# Processing trajectory (131/434)
# Processing trajectory (132/434)
# Processing trajectory (133/434)
# Processing trajectory (134/434)
# Processing trajectory (135/434)
# Processing trajectory (136/434)
# Processing trajectory (137/434)
# Processing trajectory (138/434)
# Processing trajectory (139/434)
# Processing trajectory (140/434)
# Processing trajectory (141/434)
# Processing trajectory (142/434)
# Processing trajectory (143/434)
# Processing trajectory (144/434)
# Processing trajectory (145/434)
# Processing trajectory (146/434)
# Processing trajectory (147/434)
# Processing trajectory (148/434)
# Processing trajectory (149/434)
# Processing trajectory (150/434)
# Processing trajectory (151/434)
# Processing trajectory (152/434)
# Processing trajectory (153/434)
# Processing trajectory (154/434)
# Processing trajectory (155/434)
# Processing trajectory (156/434)
# Processing trajectory (157/434)
# Processing trajectory (158/434)
# Processing trajectory (159/434)
# Processing trajectory (160/434)
# Processing trajectory (161/434)
# Processing trajectory (162/434)
# Processing trajectory (163/434)
# Processing trajectory (164/434)
# Processing trajectory (165/434)
# Processing trajectory (166/434)
# Processing trajectory (167/434)
# Processing trajectory (168/434)
# Processing trajectory (169/434)
# Processing trajectory (170/434)
# Processing trajectory (171/434)
# Processing trajectory (172/434)
# Processing trajectory (173/434)
# Processing trajectory (174/434)
# Processing trajectory (175/434)
# Processing trajectory (176/434)
# Processing trajectory (177/434)
# Processing trajectory (178/434)
# Processing trajectory (179/434)
# Processing trajectory (180/434)
# Processing trajectory (181/434)
# Processing trajectory (182/434)
# Processing trajectory (183/434)
# Processing trajectory (184/434)
# Processing trajectory (185/434)
# Processing trajectory (186/434)
# Processing trajectory (187/434)
# Processing trajectory (188/434)
# Processing trajectory (189/434)
# Processing trajectory (190/434)
# Processing trajectory (191/434)
# Processing trajectory (192/434)
# Processing trajectory (193/434)
# Processing trajectory (194/434)
# Processing trajectory (195/434)
# Processing trajectory (196/434)
# Processing trajectory (197/434)
# Processing trajectory (198/434)
# Processing trajectory (199/434)
# Processing trajectory (200/434)
# Processing trajectory (201/434)
# Processing trajectory (202/434)
# Processing trajectory (203/434)
# Processing trajectory (204/434)
# Processing trajectory (205/434)
# Processing trajectory (206/434)
# Processing trajectory (207/434)
# Processing trajectory (208/434)
# Processing trajectory (209/434)
# Processing trajectory (210/434)
# Processing trajectory (211/434)
# Processing trajectory (212/434)
# Processing trajectory (213/434)
# Processing trajectory (214/434)
# Processing trajectory (215/434)
# Processing trajectory (216/434)
# Processing trajectory (217/434)
# Processing trajectory (218/434)
# Processing trajectory (219/434)
# Processing trajectory (220/434)
# Processing trajectory (221/434)
# Processing trajectory (222/434)
# Processing trajectory (223/434)
# Processing trajectory (224/434)
# Processing trajectory (225/434)
# Processing trajectory (226/434)
# Processing trajectory (227/434)
# Processing trajectory (228/434)
# Processing trajectory (229/434)
# Processing trajectory (230/434)
# Processing trajectory (231/434)
# Processing trajectory (232/434)
# Processing trajectory (233/434)
# Processing trajectory (234/434)
# Processing trajectory (235/434)
# Processing trajectory (236/434)
# Processing trajectory (237/434)
# Processing trajectory (238/434)
# Processing trajectory (239/434)
# Processing trajectory (240/434)
# Processing trajectory (241/434)
# Processing trajectory (242/434)
# Processing trajectory (243/434)
# Processing trajectory (244/434)
# Processing trajectory (245/434)
# Processing trajectory (246/434)
# Processing trajectory (247/434)
# Processing trajectory (248/434)
# Processing trajectory (249/434)
# Processing trajectory (250/434)
# Processing trajectory (251/434)
# Processing trajectory (252/434)
# Processing trajectory (253/434)
# Processing trajectory (254/434)
# Processing trajectory (255/434)
# Processing trajectory (256/434)
# Processing trajectory (257/434)
# Processing trajectory (258/434)
# Processing trajectory (259/434)
# Processing trajectory (260/434)
# Processing trajectory (261/434)
# Processing trajectory (262/434)
# Processing trajectory (263/434)
# Processing trajectory (264/434)
# Processing trajectory (265/434)
# Processing trajectory (266/434)
# Processing trajectory (267/434)
# Processing trajectory (268/434)
# Processing trajectory (269/434)
# Processing trajectory (270/434)
# Processing trajectory (271/434)
# Processing trajectory (272/434)
# Processing trajectory (273/434)
# Processing trajectory (274/434)
# Processing trajectory (275/434)
# Processing trajectory (276/434)
# Processing trajectory (277/434)
# Processing trajectory (278/434)
# Processing trajectory (279/434)
# Processing trajectory (280/434)
# Processing trajectory (281/434)
# Processing trajectory (282/434)
# Processing trajectory (283/434)
# Processing trajectory (284/434)
# Processing trajectory (285/434)
# Processing trajectory (286/434)
# Processing trajectory (287/434)
# Processing trajectory (288/434)
# Processing trajectory (289/434)
# Processing trajectory (290/434)
# Processing trajectory (291/434)
# Processing trajectory (292/434)
# Processing trajectory (293/434)
# Processing trajectory (294/434)
# Processing trajectory (295/434)
# Processing trajectory (296/434)
# Processing trajectory (297/434)
# Processing trajectory (298/434)
# Processing trajectory (299/434)
# Processing trajectory (300/434)
# Processing trajectory (301/434)
# Processing trajectory (302/434)
# Processing trajectory (303/434)
# Processing trajectory (304/434)
# Processing trajectory (305/434)
# Processing trajectory (306/434)
# Processing trajectory (307/434)
# Processing trajectory (308/434)
# Processing trajectory (309/434)
# Processing trajectory (310/434)
# Processing trajectory (311/434)
# Processing trajectory (312/434)
# Processing trajectory (313/434)
# Processing trajectory (314/434)
# Processing trajectory (315/434)
# Processing trajectory (316/434)
# Processing trajectory (317/434)
# Processing trajectory (318/434)
# Processing trajectory (319/434)
# Processing trajectory (320/434)
# Processing trajectory (321/434)
# Processing trajectory (322/434)
# Processing trajectory (323/434)
# Processing trajectory (324/434)
# Processing trajectory (325/434)
# Processing trajectory (326/434)
# Processing trajectory (327/434)
# Processing trajectory (328/434)
# Processing trajectory (329/434)
# Processing trajectory (330/434)
# Processing trajectory (331/434)
# Processing trajectory (332/434)
# Processing trajectory (333/434)
# Processing trajectory (334/434)
# Processing trajectory (335/434)
# Processing trajectory (336/434)
# Processing trajectory (337/434)
# Processing trajectory (338/434)
# Processing trajectory (339/434)
# Processing trajectory (340/434)
# Processing trajectory (341/434)
# Processing trajectory (342/434)
# Processing trajectory (343/434)
# Processing trajectory (344/434)
# Processing trajectory (345/434)
# Processing trajectory (346/434)
# Processing trajectory (347/434)
# Processing trajectory (348/434)
# Processing trajectory (349/434)
# Processing trajectory (350/434)
# Processing trajectory (351/434)
# Processing trajectory (352/434)
# Processing trajectory (353/434)
# Processing trajectory (354/434)
# Processing trajectory (355/434)
# Processing trajectory (356/434)
# Processing trajectory (357/434)
# Processing trajectory (358/434)
# Processing trajectory (359/434)
# Processing trajectory (360/434)
# Processing trajectory (361/434)
# Processing trajectory (362/434)
# Processing trajectory (363/434)
# Processing trajectory (364/434)
# Processing trajectory (365/434)
# Processing trajectory (366/434)
# Processing trajectory (367/434)
# Processing trajectory (368/434)
# Processing trajectory (369/434)
# Processing trajectory (370/434)
# Processing trajectory (371/434)
# Processing trajectory (372/434)
# Processing trajectory (373/434)
# Processing trajectory (374/434)
# Processing trajectory (375/434)
# Processing trajectory (376/434)
# Processing trajectory (377/434)
# Processing trajectory (378/434)
# Processing trajectory (379/434)
# Processing trajectory (380/434)
# Processing trajectory (381/434)
# Processing trajectory (382/434)
# Processing trajectory (383/434)
# Processing trajectory (384/434)
# Processing trajectory (385/434)
# Processing trajectory (386/434)
# Processing trajectory (387/434)
# Processing trajectory (388/434)
# Processing trajectory (389/434)
# Processing trajectory (390/434)
# Processing trajectory (391/434)
# Processing trajectory (392/434)
# Processing trajectory (393/434)
# Processing trajectory (394/434)
# Processing trajectory (395/434)
# Processing trajectory (396/434)
# Processing trajectory (397/434)
# Processing trajectory (398/434)
# Processing trajectory (399/434)
# Processing trajectory (400/434)
# Processing trajectory (401/434)
# Processing trajectory (402/434)
# Processing trajectory (403/434)
# Processing trajectory (404/434)
# Processing trajectory (405/434)
# Processing trajectory (406/434)
# Processing trajectory (407/434)
# Processing trajectory (408/434)
# Processing trajectory (409/434)
# Processing trajectory (410/434)
# Processing trajectory (411/434)
# Processing trajectory (412/434)
# Processing trajectory (413/434)
# Processing trajectory (414/434)
# Processing trajectory (415/434)
# Processing trajectory (416/434)
# Processing trajectory (417/434)
# Processing trajectory (418/434)
# Processing trajectory (419/434)
# Processing trajectory (420/434)
# Processing trajectory (421/434)
# Processing trajectory (422/434)
# Processing trajectory (423/434)
# Processing trajectory (424/434)
# Processing trajectory (425/434)
# Processing trajectory (426/434)
# Processing trajectory (427/434)
# Processing trajectory (428/434)
# Processing trajectory (429/434)
# Processing trajectory (430/434)
# Processing trajectory (431/434)
# Processing trajectory (432/434)
# Processing trajectory (433/434)
# Processing trajectory (434/434)

# %%
trajectories
# Out:
#               Start Time             End Time Transportation Mode  \
# 0    2007/06/26 11:32:29  2007/06/26 11:40:29                 bus
# 1    2008/03/28 14:52:54  2008/03/28 15:59:59               train
# 2    2008/03/28 16:00:00  2008/03/28 22:02:00               train
# 3    2008/03/29 01:27:50  2008/03/29 15:59:59               train
# 4    2008/03/29 16:00:00  2008/03/30 15:59:59               train
# ..                   ...                  ...                 ...
# 429  2008/12/07 10:30:54  2008/12/07 10:34:14                taxi
# 430  2008/12/07 10:59:29  2008/12/07 11:29:48               train
# 431  2008/12/07 11:43:12  2008/12/07 12:23:26                 bus
# 432  2008/12/07 12:23:34  2008/12/07 12:25:07                walk
# 433  2008/12/07 12:25:34  2008/12/07 12:37:28                taxi
#
#                                Identifier
# 0    e76bf222-b1a3-11ed-b9a9-d683eb738645
# 1    fb876924-b1a3-11ed-99a2-d683eb738645
# 2    0f7368f5-b1a4-11ed-8412-d683eb738645
# 3    2536cbd4-b1a4-11ed-ae23-d683eb738645
# 4    3c7a96c4-b1a4-11ed-99f5-d683eb738645
# ..                                    ...
# 429  fffed867-b1cb-11ed-ab93-d683eb738645
# 430  136d7d91-b1cc-11ed-bbca-d683eb738645
# 431  28d5cf3d-b1cc-11ed-b41f-d683eb738645
# 432  440ebbb1-b1cc-11ed-899c-d683eb738645
# 433  5780d856-b1cc-11ed-ace3-d683eb738645
#
# [434 rows x 4 columns]

# %%
gps_points_df
# Out:
#                                 Identifier            Timestamp   Latitude  \
# 0     d8f01f95-b1cb-11ed-8c90-d683eb738645  2007-08-04 03:30:32  39.921712
# 1     d8f01f95-b1cb-11ed-8c90-d683eb738645  2007-08-04 03:30:33  39.921705
# 2     d8f01f95-b1cb-11ed-8c90-d683eb738645  2007-08-04 03:30:34  39.921695
# 3     d8f01f95-b1cb-11ed-8c90-d683eb738645  2007-08-04 03:30:35  39.921683
# 4     d8f01f95-b1cb-11ed-8c90-d683eb738645  2007-08-04 03:30:36  39.921672
# ...                                    ...                  ...        ...
# 2738  28d5cf3d-b1cc-11ed-b41f-d683eb738645  2009-03-21 05:34:49  39.136261
# 2739  28d5cf3d-b1cc-11ed-b41f-d683eb738645  2009-03-21 05:34:50  39.136256
# 2740  28d5cf3d-b1cc-11ed-b41f-d683eb738645  2009-03-21 05:34:51  39.136256
# 2741  28d5cf3d-b1cc-11ed-b41f-d683eb738645  2009-03-21 05:34:52  39.136256
# 2742  28d5cf3d-b1cc-11ed-b41f-d683eb738645  2009-03-21 05:34:53  39.136253
#
#        Longitude Altitude Label
# 0     116.472343       13  walk
# 1     116.472343       13  walk
# 2     116.472345       13  walk
# 3     116.472342       13  walk
# 4     116.472342       13  walk
# ...          ...      ...   ...
# 2738  117.218261      -59   bus
# 2739  117.218276      -59   bus
# 2740  117.218291      -59   bus
# 2741  117.218303      -59   bus
# 2742   117.21831      -59   bus
#
# [935576 rows x 6 columns]

# %%
trajectories.to_csv('dataframes/trajectories_singlesample.csv', index = False, encoding='utf-8')
gps_points_df.to_csv('dataframes/gps_points_df_singlesample.csv', index = False, encoding='utf-8')
