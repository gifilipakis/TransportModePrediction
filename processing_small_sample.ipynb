# %%
import os
import pandas as pd
import uuid
from datetime import datetime

# %%
def check_labels_file(folder):
    subfolders = os.listdir(folder)
    dfs = []
    for i, sf in enumerate(subfolders):
        user_folder = os.path.join(folder,sf)
        labels_file = os.path.join(user_folder, 'labels.txt')
        if os.path.exists(labels_file):
            print('Reading user %s ---------------------------' % (sf))
check_labels_file('small_sample')
# Out:
# Reading user 020 ---------------------------
# Reading user 021 ---------------------------
# Reading user 052 ---------------------------
# Reading user 053 ---------------------------
# Reading user 056 ---------------------------

# %%
''' 
Ao ler os usuários, verificar a existência do arquivo labels.txt
'''
def create_base_dataframes(folder):
    subfolders = os.listdir(folder)
    dfs = []
    
    # df com cada linha sendo uma trajetória classificada
    transport_df = pd.DataFrame(columns=['Start Time','End Time','Transportation Mode'])
    
    # df com cada linha sendo um registro de gps com o identificador da trajetória
    gps_points_df = pd.DataFrame(columns=['Identifier', 'Timestamp', 'Latitude', 'Longitude', 'Altitude', 'Label'])
    
    for i, sf in enumerate(subfolders):
        user_folder = os.path.join(folder,sf)
        labels_file = os.path.join(user_folder, 'labels.txt')
        
        print('Reading user %s ---------------------------' % (sf))
        
        # cria uma tabela do usuário em que cada linha é uma trajetória
        u_transport_df = pd.read_csv(labels_file, sep="\t")
        u_transport_df['Identifier'] = 0
        
        transport_df = pd.concat((transport_df,u_transport_df),axis=0)
        # cria uma tabela do usuário que contém todos os seus registros de gps
#             u_gps_points_df = pd.DataFrame(columns=['Identifier', 'Timestamp', 'Latitude', 'Longitude', 'Altitude', 'Label'])
            
        plt_files = os.path.join(user_folder, 'Trajectory')
        
        for filename in os.listdir(plt_files): 
            u_gps_points_df = pd.read_csv(os.path.join(plt_files, filename), skiprows=6, header=None,
                                  parse_dates=[[5, 6]], infer_datetime_format=True)
            u_gps_points_df.rename(inplace=True, columns={'5_6': 'Timestamp', 0: 'Latitude', 
                                                  1: 'Longitude', 3: 'Altitude'})
            u_gps_points_df.drop(inplace=True, columns=[2, 4])
        
            gps_points_df = pd.concat((gps_points_df,u_gps_points_df),axis=0)
    
    return transport_df,gps_points_df

def label_trajectories(transport_df,gps_points_df):
    count = 1
    total = transport_df.shape[0]
    for index_transport,row_transport in transport_df.iterrows():
        print('Processing trajectory (%s/%s)' % (count,total))
        
        identifier = uuid.uuid1() # identifiers are repeating in trajectories. How to create unique ones?
        
        transport_df.loc[index_transport, 'Identifier'] = identifier
        
        start = datetime.strptime(row_transport['Start Time'],'%Y/%m/%d %H:%M:%S')
        end = datetime.strptime(row_transport['End Time'],'%Y/%m/%d %H:%M:%S')
        label = row_transport['Transportation Mode']
        
        for index_gps,row_gps in gps_points_df.iterrows():
            if start <= row_gps['Timestamp'] <= end:
                gps_points_df.loc[index_gps,'Identifier'] = identifier
                gps_points_df.loc[index_gps,'Label'] = label
                
        count += 1
        
    return transport_df,gps_points_df

# %%
trajectories,gps_points_df = create_base_dataframes('small_sample')
trajectories,gps_points_df = label_trajectories(trajectories,gps_points_df)
# Out:
# Reading user 020 ---------------------------
# Reading user 021 ---------------------------
# Reading user 052 ---------------------------
# Reading user 053 ---------------------------
# Reading user 056 ---------------------------
# Processing trajectory (1/719)
# Processing trajectory (2/719)
# Processing trajectory (3/719)
# Processing trajectory (4/719)
# Processing trajectory (5/719)
# Processing trajectory (6/719)
# Processing trajectory (7/719)
# Processing trajectory (8/719)
# Processing trajectory (9/719)
# Processing trajectory (10/719)
# Processing trajectory (11/719)
# Processing trajectory (12/719)
# Processing trajectory (13/719)
# Processing trajectory (14/719)
# Processing trajectory (15/719)
# Processing trajectory (16/719)
# Processing trajectory (17/719)
# Processing trajectory (18/719)
# Processing trajectory (19/719)
# Processing trajectory (20/719)
# Processing trajectory (21/719)
# Processing trajectory (22/719)
# Processing trajectory (23/719)
# Processing trajectory (24/719)
# Processing trajectory (25/719)
# Processing trajectory (26/719)
# Processing trajectory (27/719)
# Processing trajectory (28/719)
# Processing trajectory (29/719)
# Processing trajectory (30/719)
# Processing trajectory (31/719)
# Processing trajectory (32/719)
# Processing trajectory (33/719)
# Processing trajectory (34/719)
# Processing trajectory (35/719)
# Processing trajectory (36/719)
# Processing trajectory (37/719)
# Processing trajectory (38/719)
# Processing trajectory (39/719)
# Processing trajectory (40/719)
# Processing trajectory (41/719)
# Processing trajectory (42/719)
# Processing trajectory (43/719)
# Processing trajectory (44/719)
# Processing trajectory (45/719)
# Processing trajectory (46/719)
# Processing trajectory (47/719)
# Processing trajectory (48/719)
# Processing trajectory (49/719)
# Processing trajectory (50/719)
# Processing trajectory (51/719)
# Processing trajectory (52/719)
# Processing trajectory (53/719)
# Processing trajectory (54/719)
# Processing trajectory (55/719)
# Processing trajectory (56/719)
# Processing trajectory (57/719)
# Processing trajectory (58/719)
# Processing trajectory (59/719)
# Processing trajectory (60/719)
# Processing trajectory (61/719)
# Processing trajectory (62/719)
# Processing trajectory (63/719)
# Processing trajectory (64/719)
# Processing trajectory (65/719)
# Processing trajectory (66/719)
# Processing trajectory (67/719)
# Processing trajectory (68/719)
# Processing trajectory (69/719)
# Processing trajectory (70/719)
# Processing trajectory (71/719)
# Processing trajectory (72/719)
# Processing trajectory (73/719)
# Processing trajectory (74/719)
# Processing trajectory (75/719)
# Processing trajectory (76/719)
# Processing trajectory (77/719)
# Processing trajectory (78/719)
# Processing trajectory (79/719)
# Processing trajectory (80/719)
# Processing trajectory (81/719)
# Processing trajectory (82/719)
# Processing trajectory (83/719)
# Processing trajectory (84/719)
# Processing trajectory (85/719)
# Processing trajectory (86/719)
# Processing trajectory (87/719)
# Processing trajectory (88/719)
# Processing trajectory (89/719)
# Processing trajectory (90/719)
# Processing trajectory (91/719)
# Processing trajectory (92/719)
# Processing trajectory (93/719)
# Processing trajectory (94/719)
# Processing trajectory (95/719)
# Processing trajectory (96/719)
# Processing trajectory (97/719)
# Processing trajectory (98/719)
# Processing trajectory (99/719)
# Processing trajectory (100/719)
# Processing trajectory (101/719)
# Processing trajectory (102/719)
# Processing trajectory (103/719)
# Processing trajectory (104/719)
# Processing trajectory (105/719)
# Processing trajectory (106/719)
# Processing trajectory (107/719)
# Processing trajectory (108/719)
# Processing trajectory (109/719)
# Processing trajectory (110/719)
# Processing trajectory (111/719)
# Processing trajectory (112/719)
# Processing trajectory (113/719)
# Processing trajectory (114/719)
# Processing trajectory (115/719)
# Processing trajectory (116/719)
# Processing trajectory (117/719)
# Processing trajectory (118/719)
# Processing trajectory (119/719)
# Processing trajectory (120/719)
# Processing trajectory (121/719)
# Processing trajectory (122/719)
# Processing trajectory (123/719)
# Processing trajectory (124/719)
# Processing trajectory (125/719)
# Processing trajectory (126/719)
# Processing trajectory (127/719)
# Processing trajectory (128/719)
# Processing trajectory (129/719)
# Processing trajectory (130/719)
# Processing trajectory (131/719)
# Processing trajectory (132/719)
# Processing trajectory (133/719)
# Processing trajectory (134/719)
# Processing trajectory (135/719)
# Processing trajectory (136/719)
# Processing trajectory (137/719)
# Processing trajectory (138/719)
# Processing trajectory (139/719)
# Processing trajectory (140/719)
# Processing trajectory (141/719)
# Processing trajectory (142/719)
# Processing trajectory (143/719)
# Processing trajectory (144/719)
# Processing trajectory (145/719)
# Processing trajectory (146/719)
# Processing trajectory (147/719)
# Processing trajectory (148/719)
# Processing trajectory (149/719)
# Processing trajectory (150/719)
# Processing trajectory (151/719)
# Processing trajectory (152/719)
# Processing trajectory (153/719)
# Processing trajectory (154/719)
# Processing trajectory (155/719)
# Processing trajectory (156/719)
# Processing trajectory (157/719)
# Processing trajectory (158/719)
# Processing trajectory (159/719)
# Processing trajectory (160/719)
# Processing trajectory (161/719)
# Processing trajectory (162/719)
# Processing trajectory (163/719)
# Processing trajectory (164/719)
# Processing trajectory (165/719)
# Processing trajectory (166/719)
# Processing trajectory (167/719)
# Processing trajectory (168/719)
# Processing trajectory (169/719)
# Processing trajectory (170/719)
# Processing trajectory (171/719)
# Processing trajectory (172/719)
# Processing trajectory (173/719)
# Processing trajectory (174/719)
# Processing trajectory (175/719)
# Processing trajectory (176/719)
# Processing trajectory (177/719)
# Processing trajectory (178/719)
# Processing trajectory (179/719)
# Processing trajectory (180/719)
# Processing trajectory (181/719)
# Processing trajectory (182/719)
# Processing trajectory (183/719)
# Processing trajectory (184/719)
# Processing trajectory (185/719)
# Processing trajectory (186/719)
# Processing trajectory (187/719)
# Processing trajectory (188/719)
# Processing trajectory (189/719)
# Processing trajectory (190/719)
# Processing trajectory (191/719)
# Processing trajectory (192/719)
# Processing trajectory (193/719)
# Processing trajectory (194/719)
# Processing trajectory (195/719)
# Processing trajectory (196/719)
# Processing trajectory (197/719)
# Processing trajectory (198/719)
# Processing trajectory (199/719)
# Processing trajectory (200/719)
# Processing trajectory (201/719)
# Processing trajectory (202/719)
# Processing trajectory (203/719)
# Processing trajectory (204/719)
# Processing trajectory (205/719)
# Processing trajectory (206/719)
# Processing trajectory (207/719)
# Processing trajectory (208/719)
# Processing trajectory (209/719)
# Processing trajectory (210/719)
# Processing trajectory (211/719)
# Processing trajectory (212/719)
# Processing trajectory (213/719)
# Processing trajectory (214/719)
# Processing trajectory (215/719)
# Processing trajectory (216/719)
# Processing trajectory (217/719)
# Processing trajectory (218/719)
# Processing trajectory (219/719)
# Processing trajectory (220/719)
# Processing trajectory (221/719)
# Processing trajectory (222/719)
# Processing trajectory (223/719)
# Processing trajectory (224/719)
# Processing trajectory (225/719)
# Processing trajectory (226/719)
# Processing trajectory (227/719)
# Processing trajectory (228/719)
# Processing trajectory (229/719)
# Processing trajectory (230/719)
# Processing trajectory (231/719)
# Processing trajectory (232/719)
# Processing trajectory (233/719)
# Processing trajectory (234/719)
# Processing trajectory (235/719)
# Processing trajectory (236/719)
# Processing trajectory (237/719)
# Processing trajectory (238/719)
# Processing trajectory (239/719)
# Processing trajectory (240/719)
# Processing trajectory (241/719)
# Processing trajectory (242/719)
# Processing trajectory (243/719)
# Processing trajectory (244/719)
# Processing trajectory (245/719)
# Processing trajectory (246/719)
# Processing trajectory (247/719)
# Processing trajectory (248/719)
# Processing trajectory (249/719)
# Processing trajectory (250/719)
# Processing trajectory (251/719)
# Processing trajectory (252/719)
# Processing trajectory (253/719)
# Processing trajectory (254/719)
# Processing trajectory (255/719)
# Processing trajectory (256/719)
# Processing trajectory (257/719)
# Processing trajectory (258/719)
# Processing trajectory (259/719)
# Processing trajectory (260/719)
# Processing trajectory (261/719)
# Processing trajectory (262/719)
# Processing trajectory (263/719)
# Processing trajectory (264/719)
# Processing trajectory (265/719)
# Processing trajectory (266/719)
# Processing trajectory (267/719)
# Processing trajectory (268/719)
# Processing trajectory (269/719)
# Processing trajectory (270/719)
# Processing trajectory (271/719)
# Processing trajectory (272/719)
# Processing trajectory (273/719)
# Processing trajectory (274/719)
# Processing trajectory (275/719)
# Processing trajectory (276/719)
# Processing trajectory (277/719)
# Processing trajectory (278/719)
# Processing trajectory (279/719)
# Processing trajectory (280/719)
# Processing trajectory (281/719)
# Processing trajectory (282/719)
# Processing trajectory (283/719)
# Processing trajectory (284/719)
# Processing trajectory (285/719)
# Processing trajectory (286/719)
# Processing trajectory (287/719)
# Processing trajectory (288/719)
# Processing trajectory (289/719)
# Processing trajectory (290/719)
# Processing trajectory (291/719)
# Processing trajectory (292/719)
# Processing trajectory (293/719)
# Processing trajectory (294/719)
# Processing trajectory (295/719)
# Processing trajectory (296/719)
# Processing trajectory (297/719)
# Processing trajectory (298/719)
# Processing trajectory (299/719)
# Processing trajectory (300/719)
# Processing trajectory (301/719)
# Processing trajectory (302/719)
# Processing trajectory (303/719)
# Processing trajectory (304/719)
# Processing trajectory (305/719)
# Processing trajectory (306/719)
# Processing trajectory (307/719)
# Processing trajectory (308/719)
# Processing trajectory (309/719)
# Processing trajectory (310/719)
# Processing trajectory (311/719)
# Processing trajectory (312/719)
# Processing trajectory (313/719)
# Processing trajectory (314/719)
# Processing trajectory (315/719)
# Processing trajectory (316/719)
# Processing trajectory (317/719)
# Processing trajectory (318/719)
# Processing trajectory (319/719)
# Processing trajectory (320/719)
# Processing trajectory (321/719)
# Processing trajectory (322/719)
# Processing trajectory (323/719)
# Processing trajectory (324/719)
# Processing trajectory (325/719)
# Processing trajectory (326/719)
# Processing trajectory (327/719)
# Processing trajectory (328/719)
# Processing trajectory (329/719)
# Processing trajectory (330/719)
# Processing trajectory (331/719)
# Processing trajectory (332/719)
# Processing trajectory (333/719)
# Processing trajectory (334/719)
# Processing trajectory (335/719)
# Processing trajectory (336/719)
# Processing trajectory (337/719)
# Processing trajectory (338/719)
# Processing trajectory (339/719)
# Processing trajectory (340/719)
# Processing trajectory (341/719)
# Processing trajectory (342/719)
# Processing trajectory (343/719)
# Processing trajectory (344/719)
# Processing trajectory (345/719)
# Processing trajectory (346/719)
# Processing trajectory (347/719)
# Processing trajectory (348/719)
# Processing trajectory (349/719)
# Processing trajectory (350/719)
# Processing trajectory (351/719)
# Processing trajectory (352/719)
# Processing trajectory (353/719)
# Processing trajectory (354/719)
# Processing trajectory (355/719)
# Processing trajectory (356/719)
# Processing trajectory (357/719)
# Processing trajectory (358/719)
# Processing trajectory (359/719)
# Processing trajectory (360/719)
# Processing trajectory (361/719)
# Processing trajectory (362/719)
# Processing trajectory (363/719)
# Processing trajectory (364/719)
# Processing trajectory (365/719)
# Processing trajectory (366/719)
# Processing trajectory (367/719)
# Processing trajectory (368/719)
# Processing trajectory (369/719)
# Processing trajectory (370/719)
# Processing trajectory (371/719)
# Processing trajectory (372/719)
# Processing trajectory (373/719)
# Processing trajectory (374/719)
# Processing trajectory (375/719)
# Processing trajectory (376/719)
# Processing trajectory (377/719)
# Processing trajectory (378/719)
# Processing trajectory (379/719)
# Processing trajectory (380/719)
# Processing trajectory (381/719)
# Processing trajectory (382/719)
# Processing trajectory (383/719)
# Processing trajectory (384/719)
# Processing trajectory (385/719)
# Processing trajectory (386/719)
# Processing trajectory (387/719)
# Processing trajectory (388/719)
# Processing trajectory (389/719)
# Processing trajectory (390/719)
# Processing trajectory (391/719)
# Processing trajectory (392/719)
# Processing trajectory (393/719)
# Processing trajectory (394/719)
# Processing trajectory (395/719)
# Processing trajectory (396/719)
# Processing trajectory (397/719)
# Processing trajectory (398/719)
# Processing trajectory (399/719)
# Processing trajectory (400/719)
# Processing trajectory (401/719)
# Processing trajectory (402/719)
# Processing trajectory (403/719)
# Processing trajectory (404/719)
# Processing trajectory (405/719)
# Processing trajectory (406/719)
# Processing trajectory (407/719)
# Processing trajectory (408/719)
# Processing trajectory (409/719)
# Processing trajectory (410/719)
# Processing trajectory (411/719)
# Processing trajectory (412/719)
# Processing trajectory (413/719)
# Processing trajectory (414/719)
# Processing trajectory (415/719)
# Processing trajectory (416/719)
# Processing trajectory (417/719)
# Processing trajectory (418/719)
# Processing trajectory (419/719)
# Processing trajectory (420/719)
# Processing trajectory (421/719)
# Processing trajectory (422/719)
# Processing trajectory (423/719)
# Processing trajectory (424/719)
# Processing trajectory (425/719)
# Processing trajectory (426/719)
# Processing trajectory (427/719)
# Processing trajectory (428/719)
# Processing trajectory (429/719)
# Processing trajectory (430/719)
# Processing trajectory (431/719)
# Processing trajectory (432/719)
# Processing trajectory (433/719)
# Processing trajectory (434/719)
# Processing trajectory (435/719)
# Processing trajectory (436/719)
# Processing trajectory (437/719)
# Processing trajectory (438/719)
# Processing trajectory (439/719)
# Processing trajectory (440/719)
# Processing trajectory (441/719)
# Processing trajectory (442/719)
# Processing trajectory (443/719)
# Processing trajectory (444/719)
# Processing trajectory (445/719)
# Processing trajectory (446/719)
# Processing trajectory (447/719)
# Processing trajectory (448/719)
# Processing trajectory (449/719)
# Processing trajectory (450/719)
# Processing trajectory (451/719)
# Processing trajectory (452/719)
# Processing trajectory (453/719)
# Processing trajectory (454/719)
# Processing trajectory (455/719)
# Processing trajectory (456/719)
# Processing trajectory (457/719)
# Processing trajectory (458/719)
# Processing trajectory (459/719)
# Processing trajectory (460/719)
# Processing trajectory (461/719)
# Processing trajectory (462/719)
# Processing trajectory (463/719)
# Processing trajectory (464/719)
# Processing trajectory (465/719)
# Processing trajectory (466/719)
# Processing trajectory (467/719)
# Processing trajectory (468/719)
# Processing trajectory (469/719)
# Processing trajectory (470/719)
# Processing trajectory (471/719)
# Processing trajectory (472/719)
# Processing trajectory (473/719)
# Processing trajectory (474/719)
# Processing trajectory (475/719)
# Processing trajectory (476/719)
# Processing trajectory (477/719)
# Processing trajectory (478/719)
# Processing trajectory (479/719)
# Processing trajectory (480/719)
# Processing trajectory (481/719)
# Processing trajectory (482/719)
# Processing trajectory (483/719)
# Processing trajectory (484/719)
# Processing trajectory (485/719)
# Processing trajectory (486/719)
# Processing trajectory (487/719)
# Processing trajectory (488/719)
# Processing trajectory (489/719)
# Processing trajectory (490/719)
# Processing trajectory (491/719)
# Processing trajectory (492/719)
# Processing trajectory (493/719)
# Processing trajectory (494/719)
# Processing trajectory (495/719)
# Processing trajectory (496/719)
# Processing trajectory (497/719)
# Processing trajectory (498/719)
# Processing trajectory (499/719)
# Processing trajectory (500/719)
# Processing trajectory (501/719)
# Processing trajectory (502/719)
# Processing trajectory (503/719)
# Processing trajectory (504/719)
# Processing trajectory (505/719)
# Processing trajectory (506/719)
# Processing trajectory (507/719)
# Processing trajectory (508/719)
# Processing trajectory (509/719)
# Processing trajectory (510/719)
# Processing trajectory (511/719)
# Processing trajectory (512/719)
# Processing trajectory (513/719)
# Processing trajectory (514/719)
# Processing trajectory (515/719)
# Processing trajectory (516/719)
# Processing trajectory (517/719)
# Processing trajectory (518/719)
# Processing trajectory (519/719)
# Processing trajectory (520/719)
# Processing trajectory (521/719)
# Processing trajectory (522/719)
# Processing trajectory (523/719)
# Processing trajectory (524/719)
# Processing trajectory (525/719)
# Processing trajectory (526/719)
# Processing trajectory (527/719)
# Processing trajectory (528/719)
# Processing trajectory (529/719)
# Processing trajectory (530/719)
# Processing trajectory (531/719)
# Processing trajectory (532/719)
# Processing trajectory (533/719)
# Processing trajectory (534/719)
# Processing trajectory (535/719)
# Processing trajectory (536/719)
# Processing trajectory (537/719)
# Processing trajectory (538/719)
# Processing trajectory (539/719)
# Processing trajectory (540/719)
# Processing trajectory (541/719)
# Processing trajectory (542/719)
# Processing trajectory (543/719)
# Processing trajectory (544/719)
# Processing trajectory (545/719)
# Processing trajectory (546/719)
# Processing trajectory (547/719)
# Processing trajectory (548/719)
# Processing trajectory (549/719)
# Processing trajectory (550/719)
# Processing trajectory (551/719)
# Processing trajectory (552/719)
# Processing trajectory (553/719)
# Processing trajectory (554/719)
# Processing trajectory (555/719)
# Processing trajectory (556/719)
# Processing trajectory (557/719)
# Processing trajectory (558/719)
# Processing trajectory (559/719)
# Processing trajectory (560/719)
# Processing trajectory (561/719)
# Processing trajectory (562/719)
# Processing trajectory (563/719)
# Processing trajectory (564/719)
# Processing trajectory (565/719)
# Processing trajectory (566/719)
# Processing trajectory (567/719)
# Processing trajectory (568/719)
# Processing trajectory (569/719)
# Processing trajectory (570/719)
# Processing trajectory (571/719)
# Processing trajectory (572/719)
# Processing trajectory (573/719)
# Processing trajectory (574/719)
# Processing trajectory (575/719)
# Processing trajectory (576/719)
# Processing trajectory (577/719)
# Processing trajectory (578/719)
# Processing trajectory (579/719)
# Processing trajectory (580/719)
# Processing trajectory (581/719)
# Processing trajectory (582/719)
# Processing trajectory (583/719)
# Processing trajectory (584/719)
# Processing trajectory (585/719)
# Processing trajectory (586/719)
# Processing trajectory (587/719)
# Processing trajectory (588/719)
# Processing trajectory (589/719)
# Processing trajectory (590/719)
# Processing trajectory (591/719)
# Processing trajectory (592/719)
# Processing trajectory (593/719)
# Processing trajectory (594/719)
# Processing trajectory (595/719)
# Processing trajectory (596/719)
# Processing trajectory (597/719)
# Processing trajectory (598/719)
# Processing trajectory (599/719)
# Processing trajectory (600/719)
# Processing trajectory (601/719)
# Processing trajectory (602/719)
# Processing trajectory (603/719)
# Processing trajectory (604/719)
# Processing trajectory (605/719)
# Processing trajectory (606/719)
# Processing trajectory (607/719)
# Processing trajectory (608/719)
# Processing trajectory (609/719)
# Processing trajectory (610/719)
# Processing trajectory (611/719)
# Processing trajectory (612/719)
# Processing trajectory (613/719)
# Processing trajectory (614/719)
# Processing trajectory (615/719)
# Processing trajectory (616/719)
# Processing trajectory (617/719)
# Processing trajectory (618/719)
# Processing trajectory (619/719)
# Processing trajectory (620/719)
# Processing trajectory (621/719)
# Processing trajectory (622/719)
# Processing trajectory (623/719)
# Processing trajectory (624/719)
# Processing trajectory (625/719)
# Processing trajectory (626/719)
# Processing trajectory (627/719)
# Processing trajectory (628/719)
# Processing trajectory (629/719)
# Processing trajectory (630/719)
# Processing trajectory (631/719)
# Processing trajectory (632/719)
# Processing trajectory (633/719)
# Processing trajectory (634/719)
# Processing trajectory (635/719)
# Processing trajectory (636/719)
# Processing trajectory (637/719)
# Processing trajectory (638/719)
# Processing trajectory (639/719)
# Processing trajectory (640/719)
# Processing trajectory (641/719)
# Processing trajectory (642/719)
# Processing trajectory (643/719)
# Processing trajectory (644/719)
# Processing trajectory (645/719)
# Processing trajectory (646/719)
# Processing trajectory (647/719)
# Processing trajectory (648/719)
# Processing trajectory (649/719)
# Processing trajectory (650/719)
# Processing trajectory (651/719)
# Processing trajectory (652/719)
# Processing trajectory (653/719)
# Processing trajectory (654/719)
# Processing trajectory (655/719)
# Processing trajectory (656/719)
# Processing trajectory (657/719)
# Processing trajectory (658/719)
# Processing trajectory (659/719)
# Processing trajectory (660/719)
# Processing trajectory (661/719)
# Processing trajectory (662/719)
# Processing trajectory (663/719)
# Processing trajectory (664/719)
# Processing trajectory (665/719)
# Processing trajectory (666/719)
# Processing trajectory (667/719)
# Processing trajectory (668/719)
# Processing trajectory (669/719)
# Processing trajectory (670/719)
# Processing trajectory (671/719)
# Processing trajectory (672/719)
# Processing trajectory (673/719)
# Processing trajectory (674/719)
# Processing trajectory (675/719)
# Processing trajectory (676/719)
# Processing trajectory (677/719)
# Processing trajectory (678/719)
# Processing trajectory (679/719)
# Processing trajectory (680/719)
# Processing trajectory (681/719)
# Processing trajectory (682/719)
# Processing trajectory (683/719)
# Processing trajectory (684/719)
# Processing trajectory (685/719)
# Processing trajectory (686/719)
# Processing trajectory (687/719)
# Processing trajectory (688/719)
# Processing trajectory (689/719)
# Processing trajectory (690/719)
# Processing trajectory (691/719)
# Processing trajectory (692/719)
# Processing trajectory (693/719)
# Processing trajectory (694/719)
# Processing trajectory (695/719)
# Processing trajectory (696/719)
# Processing trajectory (697/719)
# Processing trajectory (698/719)
# Processing trajectory (699/719)
# Processing trajectory (700/719)
# Processing trajectory (701/719)
# Processing trajectory (702/719)
# Processing trajectory (703/719)
# Processing trajectory (704/719)
# Processing trajectory (705/719)
# Processing trajectory (706/719)
# Processing trajectory (707/719)
# Processing trajectory (708/719)
# Processing trajectory (709/719)
# Processing trajectory (710/719)
# Processing trajectory (711/719)
# Processing trajectory (712/719)
# Processing trajectory (713/719)
# Processing trajectory (714/719)
# Processing trajectory (715/719)
# Processing trajectory (716/719)
# Processing trajectory (717/719)
# Processing trajectory (718/719)
# Processing trajectory (719/719)

# %%
trajectories.to_csv('dataframes/trajectories_smallsample.csv', index = False, encoding='utf-8')
gps_points_df.to_csv('dataframes/gps_points_df_smallsample.csv', index = False, encoding='utf-8')
